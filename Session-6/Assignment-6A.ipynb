# %% [markdown]
# <a href="https://colab.research.google.com/github/sambitdash/EVA-2/blob/master/Session-6/Assignment-6A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras import backend as K
import time
import matplotlib.pyplot as plt
import numpy as np
% matplotlib inline
np.random.seed(2017) 
from keras.models import Sequential
from keras.layers.convolutional import Convolution2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dense, Dropout
from keras.layers.normalization import BatchNormalization
from keras.utils import np_utils

# %%
from keras.datasets import cifar10
(train_features, train_labels), (test_features, test_labels) = cifar10.load_data()
num_train, img_channels, img_rows, img_cols =  train_features.shape
num_test, _, _, _ =  test_features.shape
num_classes = len(np.unique(train_labels))

# %%
class_names = ['airplane','automobile','bird','cat','deer',
               'dog','frog','horse','ship','truck']
fig = plt.figure(figsize=(8,3))
for i in range(num_classes):
    ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
    idx = np.where(train_labels[:]==i)[0]
    features_idx = train_features[idx,::]
    img_num = np.random.randint(features_idx.shape[0])
    im = features_idx[img_num]
    ax.set_title(class_names[i])
    plt.imshow(im)
plt.show()

# %%
#train_features /= 255
#train_features /= 255


X_mean = np.mean(train_features, axis=0, keepdims=True)
X_std  = np.std(train_features, axis=0, keepdims=True)
X_std  = np.clip(X_std, 1.0/255, 1.0)


train_features = train_features - X_mean
test_features  = test_features  - X_mean

train_features = np.divide(train_features, X_std)
test_features  = np.divide(test_features, X_std)

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['categorical_accuracy'])+1),model_history.history['categorical_accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_categorical_accuracy'])+1),model_history.history['val_categorical_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['categorical_accuracy'])+1),len(model_history.history['categorical_accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
def accuracy(test_x, test_y, model):
    result = model.predict(test_x)
    predicted_class = np.argmax(result, axis=1)
    true_class = np.argmax(test_y, axis=1)
    num_correct = np.sum(predicted_class == true_class) 
    accuracy = float(num_correct)/result.shape[0]
    return (accuracy * 100)

# %%
train_features = train_features.astype('float32')/255
test_features = test_features.astype('float32')/255
# convert class labels to binary class labels
train_labels = np_utils.to_categorical(train_labels, num_classes)
test_labels = np_utils.to_categorical(test_labels, num_classes)

print(test_labels.shape)
# Out:
# (10000, 10)

# %%
# Define the model
model = Sequential()
model.add(Convolution2D(32, 3, 3, border_mode='same', input_shape=(32, 32, 3)))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(128, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Convolution2D(128, 3, 3))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(32, 3, 3, border_mode='same'))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Convolution2D(32, 3, 3))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Convolution2D(num_classes, 2, 2))
model.add(Dropout(0.25))
model.add(Activation('softmax'))
model.add(Flatten())
# Compile the model
model.compile(optimizer='adam', loss='poisson', metrics=['categorical_accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3))`
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3), padding="same")`
#   if __name__ == '__main__':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 3))`
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:16: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), padding="same")`
#   app.launch_new_instance()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:19: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:23: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (2, 2))`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_29 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# activation_29 (Activation)   (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_29 (Dropout)         (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 30, 30, 32)        9248
# _________________________________________________________________
# activation_30 (Activation)   (None, 30, 30, 32)        0
# _________________________________________________________________
# dropout_30 (Dropout)         (None, 30, 30, 32)        0
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 15, 15, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 15, 15, 128)       36992
# _________________________________________________________________
# activation_31 (Activation)   (None, 15, 15, 128)       0
# _________________________________________________________________
# dropout_31 (Dropout)         (None, 15, 15, 128)       0
# _________________________________________________________________
# conv2d_32 (Conv2D)           (None, 13, 13, 128)       147584
# _________________________________________________________________
# activation_32 (Activation)   (None, 13, 13, 128)       0
# _________________________________________________________________
# dropout_32 (Dropout)         (None, 13, 13, 128)       0
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 6, 6, 32)          36896
# _________________________________________________________________
# activation_33 (Activation)   (None, 6, 6, 32)          0
# _________________________________________________________________
# dropout_33 (Dropout)         (None, 6, 6, 32)          0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 4, 4, 32)          9248
# _________________________________________________________________
# activation_34 (Activation)   (None, 4, 4, 32)          0
# _________________________________________________________________
# dropout_34 (Dropout)         (None, 4, 4, 32)          0
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 2, 2, 32)          0
# _________________________________________________________________
# conv2d_35 (Conv2D)           (None, 1, 1, 10)          1290
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 1, 1, 10)          0
# _________________________________________________________________
# activation_35 (Activation)   (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_5 (Flatten)          (None, 10)                0
# =================================================================
# Total params: 242,154
# Trainable params: 242,154
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)


# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()

# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   if sys.path[0] == '':
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:12: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   if sys.path[0] == '':
# Epoch 1/100
# 390/390 [==============================] - 19s 49ms/step - loss: 0.2890 - categorical_accuracy: 0.3060 - val_loss: 0.2715 - val_categorical_accuracy: 0.4710
# Epoch 2/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2557 - categorical_accuracy: 0.4367 - val_loss: 0.2539 - val_categorical_accuracy: 0.5730
# Epoch 3/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2405 - categorical_accuracy: 0.4943 - val_loss: 0.2291 - val_categorical_accuracy: 0.6140
# Epoch 4/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2293 - categorical_accuracy: 0.5340 - val_loss: 0.2167 - val_categorical_accuracy: 0.6735
# Epoch 5/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2204 - categorical_accuracy: 0.5626 - val_loss: 0.2105 - val_categorical_accuracy: 0.6848
# Epoch 6/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2140 - categorical_accuracy: 0.5862 - val_loss: 0.2047 - val_categorical_accuracy: 0.7118
# Epoch 7/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2090 - categorical_accuracy: 0.6015 - val_loss: 0.1970 - val_categorical_accuracy: 0.7123
# Epoch 8/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2047 - categorical_accuracy: 0.6137 - val_loss: 0.1894 - val_categorical_accuracy: 0.7453
# Epoch 9/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.2014 - categorical_accuracy: 0.6219 - val_loss: 0.1865 - val_categorical_accuracy: 0.7585
# Epoch 10/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1976 - categorical_accuracy: 0.6365 - val_loss: 0.1789 - val_categorical_accuracy: 0.7666
# Epoch 11/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1962 - categorical_accuracy: 0.6406 - val_loss: 0.1801 - val_categorical_accuracy: 0.7765
# Epoch 12/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1931 - categorical_accuracy: 0.6520 - val_loss: 0.1770 - val_categorical_accuracy: 0.7812
# Epoch 13/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1919 - categorical_accuracy: 0.6542 - val_loss: 0.1746 - val_categorical_accuracy: 0.7857
# Epoch 14/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1898 - categorical_accuracy: 0.6615 - val_loss: 0.1766 - val_categorical_accuracy: 0.7719
# Epoch 15/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1884 - categorical_accuracy: 0.6676 - val_loss: 0.1751 - val_categorical_accuracy: 0.7836
# Epoch 16/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1864 - categorical_accuracy: 0.6728 - val_loss: 0.1689 - val_categorical_accuracy: 0.7911
# Epoch 17/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1853 - categorical_accuracy: 0.6780 - val_loss: 0.1687 - val_categorical_accuracy: 0.7991
# Epoch 18/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1842 - categorical_accuracy: 0.6812 - val_loss: 0.1702 - val_categorical_accuracy: 0.7882
# Epoch 19/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1821 - categorical_accuracy: 0.6866 - val_loss: 0.1674 - val_categorical_accuracy: 0.8009
# Epoch 20/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1822 - categorical_accuracy: 0.6844 - val_loss: 0.1677 - val_categorical_accuracy: 0.7868
# Epoch 21/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1810 - categorical_accuracy: 0.6912 - val_loss: 0.1676 - val_categorical_accuracy: 0.7924
# Epoch 22/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1802 - categorical_accuracy: 0.6908 - val_loss: 0.1682 - val_categorical_accuracy: 0.7908
# Epoch 23/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1802 - categorical_accuracy: 0.6914 - val_loss: 0.1648 - val_categorical_accuracy: 0.7970
# Epoch 24/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1790 - categorical_accuracy: 0.6945 - val_loss: 0.1639 - val_categorical_accuracy: 0.8047
# Epoch 25/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1777 - categorical_accuracy: 0.7012 - val_loss: 0.1632 - val_categorical_accuracy: 0.8082
# Epoch 26/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1776 - categorical_accuracy: 0.6985 - val_loss: 0.1618 - val_categorical_accuracy: 0.8066
# Epoch 27/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1764 - categorical_accuracy: 0.7046 - val_loss: 0.1614 - val_categorical_accuracy: 0.8106
# Epoch 28/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1765 - categorical_accuracy: 0.7050 - val_loss: 0.1617 - val_categorical_accuracy: 0.8132
# Epoch 29/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1754 - categorical_accuracy: 0.7060 - val_loss: 0.1624 - val_categorical_accuracy: 0.8149
# Epoch 30/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1753 - categorical_accuracy: 0.7052 - val_loss: 0.1606 - val_categorical_accuracy: 0.8124
# Epoch 31/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1749 - categorical_accuracy: 0.7060 - val_loss: 0.1599 - val_categorical_accuracy: 0.8187
# Epoch 32/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1741 - categorical_accuracy: 0.7089 - val_loss: 0.1583 - val_categorical_accuracy: 0.8181
# Epoch 33/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1735 - categorical_accuracy: 0.7153 - val_loss: 0.1586 - val_categorical_accuracy: 0.8144
# Epoch 34/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1742 - categorical_accuracy: 0.7080 - val_loss: 0.1587 - val_categorical_accuracy: 0.8264
# Epoch 35/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1728 - categorical_accuracy: 0.7152 - val_loss: 0.1599 - val_categorical_accuracy: 0.8162
# Epoch 36/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1718 - categorical_accuracy: 0.7183 - val_loss: 0.1608 - val_categorical_accuracy: 0.8058
# Epoch 37/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1724 - categorical_accuracy: 0.7152 - val_loss: 0.1595 - val_categorical_accuracy: 0.8187
# Epoch 38/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1710 - categorical_accuracy: 0.7197 - val_loss: 0.1566 - val_categorical_accuracy: 0.8206
# Epoch 39/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1711 - categorical_accuracy: 0.7195 - val_loss: 0.1571 - val_categorical_accuracy: 0.8225
# Epoch 40/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1709 - categorical_accuracy: 0.7196 - val_loss: 0.1563 - val_categorical_accuracy: 0.8277
# Epoch 41/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1703 - categorical_accuracy: 0.7226 - val_loss: 0.1578 - val_categorical_accuracy: 0.8146
# Epoch 42/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1709 - categorical_accuracy: 0.7216 - val_loss: 0.1579 - val_categorical_accuracy: 0.8171
# Epoch 43/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1698 - categorical_accuracy: 0.7221 - val_loss: 0.1529 - val_categorical_accuracy: 0.8357
# Epoch 44/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1705 - categorical_accuracy: 0.7230 - val_loss: 0.1597 - val_categorical_accuracy: 0.8180
# Epoch 45/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1698 - categorical_accuracy: 0.7210 - val_loss: 0.1583 - val_categorical_accuracy: 0.8128
# Epoch 46/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1695 - categorical_accuracy: 0.7233 - val_loss: 0.1558 - val_categorical_accuracy: 0.8249
# Epoch 47/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1693 - categorical_accuracy: 0.7235 - val_loss: 0.1558 - val_categorical_accuracy: 0.8224
# Epoch 48/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1677 - categorical_accuracy: 0.7308 - val_loss: 0.1557 - val_categorical_accuracy: 0.8229
# Epoch 49/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1683 - categorical_accuracy: 0.7283 - val_loss: 0.1552 - val_categorical_accuracy: 0.8270
# Epoch 50/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1681 - categorical_accuracy: 0.7290 - val_loss: 0.1562 - val_categorical_accuracy: 0.8249
# Epoch 51/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1682 - categorical_accuracy: 0.7266 - val_loss: 0.1533 - val_categorical_accuracy: 0.8330
# Epoch 52/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1671 - categorical_accuracy: 0.7295 - val_loss: 0.1534 - val_categorical_accuracy: 0.8277
# Epoch 53/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1671 - categorical_accuracy: 0.7309 - val_loss: 0.1533 - val_categorical_accuracy: 0.8323
# Epoch 54/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1672 - categorical_accuracy: 0.7307 - val_loss: 0.1538 - val_categorical_accuracy: 0.8298
# Epoch 55/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1674 - categorical_accuracy: 0.7297 - val_loss: 0.1535 - val_categorical_accuracy: 0.8298
# Epoch 56/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1667 - categorical_accuracy: 0.7331 - val_loss: 0.1550 - val_categorical_accuracy: 0.8249
# Epoch 57/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1672 - categorical_accuracy: 0.7289 - val_loss: 0.1533 - val_categorical_accuracy: 0.8341
# Epoch 58/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1663 - categorical_accuracy: 0.7346 - val_loss: 0.1533 - val_categorical_accuracy: 0.8318
# Epoch 59/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1666 - categorical_accuracy: 0.7370 - val_loss: 0.1540 - val_categorical_accuracy: 0.8306
# Epoch 60/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1662 - categorical_accuracy: 0.7355 - val_loss: 0.1552 - val_categorical_accuracy: 0.8235
# Epoch 61/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1650 - categorical_accuracy: 0.7371 - val_loss: 0.1556 - val_categorical_accuracy: 0.8195
# Epoch 62/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1658 - categorical_accuracy: 0.7343 - val_loss: 0.1537 - val_categorical_accuracy: 0.8318
# Epoch 63/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1649 - categorical_accuracy: 0.7351 - val_loss: 0.1552 - val_categorical_accuracy: 0.8222
# Epoch 64/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1658 - categorical_accuracy: 0.7351 - val_loss: 0.1553 - val_categorical_accuracy: 0.8250
# Epoch 65/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1649 - categorical_accuracy: 0.7397 - val_loss: 0.1559 - val_categorical_accuracy: 0.8223
# Epoch 66/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1651 - categorical_accuracy: 0.7368 - val_loss: 0.1558 - val_categorical_accuracy: 0.8222
# Epoch 67/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1641 - categorical_accuracy: 0.7418 - val_loss: 0.1546 - val_categorical_accuracy: 0.8254
# Epoch 68/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1637 - categorical_accuracy: 0.7438 - val_loss: 0.1538 - val_categorical_accuracy: 0.8324
# Epoch 69/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1646 - categorical_accuracy: 0.7371 - val_loss: 0.1558 - val_categorical_accuracy: 0.8208
# Epoch 70/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1640 - categorical_accuracy: 0.7412 - val_loss: 0.1508 - val_categorical_accuracy: 0.8398
# Epoch 71/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1639 - categorical_accuracy: 0.7406 - val_loss: 0.1523 - val_categorical_accuracy: 0.8339
# Epoch 72/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1639 - categorical_accuracy: 0.7412 - val_loss: 0.1529 - val_categorical_accuracy: 0.8328
# Epoch 73/100
# 390/390 [==============================] - 18s 46ms/step - loss: 0.1634 - categorical_accuracy: 0.7422 - val_loss: 0.1531 - val_categorical_accuracy: 0.8335
# Epoch 74/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1636 - categorical_accuracy: 0.7407 - val_loss: 0.1532 - val_categorical_accuracy: 0.8314
# Epoch 75/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1636 - categorical_accuracy: 0.7414 - val_loss: 0.1517 - val_categorical_accuracy: 0.8347
# Epoch 76/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1636 - categorical_accuracy: 0.7387 - val_loss: 0.1516 - val_categorical_accuracy: 0.8384
# Epoch 77/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1637 - categorical_accuracy: 0.7406 - val_loss: 0.1546 - val_categorical_accuracy: 0.8273
# Epoch 78/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1628 - categorical_accuracy: 0.7457 - val_loss: 0.1520 - val_categorical_accuracy: 0.8379
# Epoch 79/100
# 390/390 [==============================] - 17s 45ms/step - loss: 0.1627 - categorical_accuracy: 0.7455 - val_loss: 0.1515 - val_categorical_accuracy: 0.8343
# Epoch 80/100
# 390/390 [==============================] - 17s 45ms/step - loss: 0.1630 - categorical_accuracy: 0.7451 - val_loss: 0.1533 - val_categorical_accuracy: 0.8277
# Epoch 81/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1626 - categorical_accuracy: 0.7458 - val_loss: 0.1519 - val_categorical_accuracy: 0.8343
# Epoch 82/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1621 - categorical_accuracy: 0.7464 - val_loss: 0.1520 - val_categorical_accuracy: 0.8319
# Epoch 83/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1625 - categorical_accuracy: 0.7450 - val_loss: 0.1520 - val_categorical_accuracy: 0.8358
# Epoch 84/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1618 - categorical_accuracy: 0.7486 - val_loss: 0.1518 - val_categorical_accuracy: 0.8360
# Epoch 85/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1622 - categorical_accuracy: 0.7466 - val_loss: 0.1526 - val_categorical_accuracy: 0.8368
# Epoch 86/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1623 - categorical_accuracy: 0.7447 - val_loss: 0.1521 - val_categorical_accuracy: 0.8296
# Epoch 87/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1611 - categorical_accuracy: 0.7500 - val_loss: 0.1505 - val_categorical_accuracy: 0.8372
# Epoch 88/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1617 - categorical_accuracy: 0.7465 - val_loss: 0.1537 - val_categorical_accuracy: 0.8268
# Epoch 89/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1623 - categorical_accuracy: 0.7451 - val_loss: 0.1533 - val_categorical_accuracy: 0.8272
# Epoch 90/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1612 - categorical_accuracy: 0.7496 - val_loss: 0.1515 - val_categorical_accuracy: 0.8397
# Epoch 91/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1616 - categorical_accuracy: 0.7484 - val_loss: 0.1532 - val_categorical_accuracy: 0.8324
# Epoch 92/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1614 - categorical_accuracy: 0.7478 - val_loss: 0.1525 - val_categorical_accuracy: 0.8304
# Epoch 93/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1608 - categorical_accuracy: 0.7509 - val_loss: 0.1512 - val_categorical_accuracy: 0.8388
# Epoch 94/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1618 - categorical_accuracy: 0.7487 - val_loss: 0.1515 - val_categorical_accuracy: 0.8390
# Epoch 95/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1609 - categorical_accuracy: 0.7500 - val_loss: 0.1505 - val_categorical_accuracy: 0.8435
# Epoch 96/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1605 - categorical_accuracy: 0.7515 - val_loss: 0.1508 - val_categorical_accuracy: 0.8369
# Epoch 97/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1610 - categorical_accuracy: 0.7514 - val_loss: 0.1505 - val_categorical_accuracy: 0.8395
# Epoch 98/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1609 - categorical_accuracy: 0.7519 - val_loss: 0.1505 - val_categorical_accuracy: 0.8364
# Epoch 99/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1603 - categorical_accuracy: 0.7509 - val_loss: 0.1517 - val_categorical_accuracy: 0.8334
# Epoch 100/100
# 390/390 [==============================] - 18s 45ms/step - loss: 0.1604 - categorical_accuracy: 0.7526 - val_loss: 0.1512 - val_categorical_accuracy: 0.8401
# Model took 1776.50 seconds to train
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-45-2f9984c78b67> in <module>()
#      14 print ("Model took %0.2f seconds to train"%(end - start))
#      15 # plot model history
# ---> 16 plot_model_history(model_info)
#      17 # compute test accuracy
#      18 print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
#
# <ipython-input-39-e05d9b01600e> in plot_model_history(model_history)
#       2     fig, axs = plt.subplots(1,2,figsize=(15,5))
#       3     # summarize history for accuracy
# ----> 4     axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
#       5     axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
#       6     axs[0].set_title('Model Accuracy')
#
# KeyError: 'acc'

# %%
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# Model took 1776.50 seconds to train
# Accuracy on test data is: 84.01
